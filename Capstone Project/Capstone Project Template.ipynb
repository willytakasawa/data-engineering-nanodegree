# %% [markdown]
# # Data Engineering Nanodegree - Capstone Project
#
# ### Project Summary
# This project aims to structure an optimized analytical database of U.S. immigration events.<br>
# The main objective is to create an ETL pipeline to build up a Data Warehouse working as a single source of data, facilitating the analysis through ad-hoc queries and helping Businesse Intelligence team to analyze treds and patterns of the immigration events.
#
#
# The project follows the follow steps:
# * Step 1: Scope the Project and Gather Data
# * Step 2: Explore and Assess the Data
# * Step 3: Define the Data Model
# * Step 4: Run ETL to Model the Data
# * Step 5: Complete Project Write Up

# %%
# Import libraries
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Row
from pyspark.sql.types import *

# %% [markdown]
# ## Step 1: Scope the Project and Gather Data
#
# ### Scope
# Explain what you plan to do in the project in more detail. What data do you use? What is your end solution look like? What tools did you use? etc>

# %% [markdown]
# ### Datasets

# %% [markdown]
# #### [I-94 Immigration Data](https://www.trade.gov/i-94-arrivals-historical-data)
# This dataset comes from the US National Tourism and Trade Office and contains information about immigrants in the U.S. <br>
# A data dictionary is included in the workspace on the following path (dictionary).
#
# ##### Data Dictionary
# | Column | Description |
# | :--- | :--- |
# | CICID | Unique ID |
# | I94YR | 4-digit year |
# | I94MON | Numeric month |
# | I94CIT | 3-digit code of source city for immigration |
# | I94RES | 3-digit code of source country for immigration |
# | I94PORT | Port admitted through |
# | ARRDATE | Arrival date in the USA |
# | I94MODE | Mode of transportation (1 = Air; 2 = Sea; 3 = Land; 9 = Not reported) |
# | I94ADDR | State of arrival |
# | DEPDATE | Departure date from the USA |
# | I94BIR | Age of Respondent in Years |
# | I94VISA | Visa codes (1 = Business; 2 = Pleasure; 3 = Student) |
# | COUNT | Used for summary statistics |
# | DTADFILE | Character Date Field |
# | VISAPOST | Department of State where Visa was issued |
# | OCCUP | Occupation that will be performed in U.S. |
# | ENTDEPA | Arrival Flag. Whether admitted or paroled into the US |
# | ENTDEPD | Departure Flag. Whether Departed, lost I-94 or is deceased |
# | ENTDEPU | Update Flag. Update of visa, Either apprehended, overstayed, adjusted to perm residence |
# | MATFLAG | Match flag - Match of arrival and departure records|
# | BIRYEAR | 4-digit year of birth |
# | DTADDTO | Character date field to when admitted in the US (allowed to stay until) |
# | GENDER | Gender |
# | INSNUM | INS number |
# | AIRLINE | Airline used to arrive in U.S. |
# | ADMNUM | Admission number |
# | FLTNO | Flight number of Airline used to arrive in U.S. |
# | VISATYPE | Class of admission legally admitting the non-immigrant to temporarily stay in U.S. |

# %%
# Read in the data here
fname = '../../data/18-83510-I94-Data-2016/i94_apr16_sub.sas7bdat'
immigration_data = pd.read_sas(fname, 'sas7bdat', encoding="ISO-8859-1")
immigration_data.head()
# Out:
#    cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode i94addr  \
# 0    6.0  2016.0     4.0   692.0   692.0     XXX  20573.0      NaN     NaN
# 1    7.0  2016.0     4.0   254.0   276.0     ATL  20551.0      1.0      AL
# 2   15.0  2016.0     4.0   101.0   101.0     WAS  20545.0      1.0      MI
# 3   16.0  2016.0     4.0   101.0   101.0     NYC  20545.0      1.0      MA
# 4   17.0  2016.0     4.0   101.0   101.0     NYC  20545.0      1.0      MA
#
#    depdate   ...     entdepu  matflag  biryear   dtaddto gender insnum  \
# 0      NaN   ...           U      NaN   1979.0  10282016    NaN    NaN
# 1      NaN   ...           Y      NaN   1991.0       D/S      M    NaN
# 2  20691.0   ...         NaN        M   1961.0  09302016      M    NaN
# 3  20567.0   ...         NaN        M   1988.0  09302016    NaN    NaN
# 4  20567.0   ...         NaN        M   2012.0  09302016    NaN    NaN
#
#   airline        admnum  fltno visatype
# 0     NaN  1.897628e+09    NaN       B2
# 1     NaN  3.736796e+09  00296       F1
# 2      OS  6.666432e+08     93       B2
# 3      AA  9.246846e+10  00199       B2
# 4      AA  9.246846e+10  00199       B2
#
# [5 rows x 28 columns]

# %% [markdown]
# #### [Airport Code](https://datahub.io/core/airport-codes#data)
# This dataset contains airport codes and corresponding cities.
# ##### Data Dictionary
# |Column       |Description
# |:-------------|:-----------
# |ident         |Unique ID
# |type          |Airport type
# |name          |Airport name
# |elevation_ft  |Airport altitude
# |continent     |Continent
# |iso_country   |Country Code
# |iso_region    |Region Conde
# |municipality  |City
# |gps_code      |Airport GPS Code
# |iata_code     |Airport IATA Code
# |local_code    |Airport local code
# |coordinates   |Airport coordinates

# %%
airport_data = pd.read_csv('raw_data/airport-codes_csv.csv')
airport_data.head()
# Out:
#   ident           type                                name  elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport          11.0
# 1  00AA  small_airport                Aero B Ranch Airport        3435.0
# 2  00AK  small_airport                        Lowell Field         450.0
# 3  00AL  small_airport                        Epps Airpark         820.0
# 4  00AR         closed  Newport Hospital & Clinic Heliport         237.0
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# 1       00AA                 -101.473911, 38.704022
# 2       00AK            -151.695999146, 59.94919968
# 3       00AL  -86.77030181884766, 34.86479949951172
# 4        NaN                    -91.254898, 35.6087

# %% [markdown]
# #### [U.S. City Demographic Data](https://public.opendatasoft.com/explore/dataset/us-cities-demographics/export/)
# This dataset contains information about the demographics of all US cities and census-designated places with a population greater or equal to 65,000.<br>
# The data comes from the US Census Bureau's 2015 American Community Survey.
# ##### Data Dictionary
# |Column                       |Description
# |:-----------------------------|:-----------
# |City |City Name
# |State |US State of the City
# |Median Age |The median population age
# |Male Population |Male population total
# |Female Population |Female population total
# |Total Population |Total population
# |Number of Veterans |Number of veterans living in the city
# |Foreign-born |Number of residents who were not born in the city
# |Average Household Size |Average size of houses in the city
# |State Code |Code of the state
# |Race |Race class
# |Count |Number of individuals in each race"

# %%
demo = pd.read_csv('raw_data/us-cities-demographics.csv', delimiter=';')
demo.head()
# Out:
#                City          State  Median Age  Male Population  \
# 0     Silver Spring       Maryland        33.8          40601.0
# 1            Quincy  Massachusetts        41.0          44129.0
# 2            Hoover        Alabama        38.5          38040.0
# 3  Rancho Cucamonga     California        34.5          88127.0
# 4            Newark     New Jersey        34.6         138040.0
#
#    Female Population  Total Population  Number of Veterans  Foreign-born  \
# 0            41862.0             82463              1562.0       30908.0
# 1            49500.0             93629              4147.0       32935.0
# 2            46799.0             84839              4819.0        8229.0
# 3            87105.0            175232              5821.0       33878.0
# 4           143873.0            281913              5829.0       86253.0
#
#    Average Household Size State Code                       Race  Count
# 0                    2.60         MD         Hispanic or Latino  25924
# 1                    2.39         MA                      White  58723
# 2                    2.58         AL                      Asian   4759
# 3                    3.18         CA  Black or African-American  24437
# 4                    2.73         NJ                      White  76402

# %% [markdown]
# #### [World Temperature Data](https://www.kaggle.com/berkeleyearth/climate-change-earth-surface-temperature-data)
# The raw data comes from the [Berkeley Earth data page](https://berkeleyearth.org/data/).<br>
# This dataset is a slice from the Global Temperatures Dataset and include Global Land Temperatures By City.
#
# ##### Data Dictionary
# |Column                        |Description
# |:-----------------------------|:-----------
# |dt                            |Reference Date
# |AverageTemperature            |Average temperature in Celsius
# |AverageTemperatureUncertainty |95% confidence interval around average temperature
# |City                          |City
# |Country                       |Country
# |Latitude                      |Latitude
# |Longitude                     |Longitude

# %%
fname = '../../data2/GlobalLandTemperaturesByCity.csv'
temp = pd.read_csv(fname)
temp.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %% [markdown]
# ## Step 2: Explore and Assess the Data

# %% [markdown]
# ### Data Cleaning & Exploratory Analysis

# %% [markdown]
# - **Airport Data**

# %%
airport_data.shape
# Out:
# (55075, 12)

# %%
# Check data types
airport_data.dtypes
# Out:
# ident            object
# type             object
# name             object
# elevation_ft    float64
# continent        object
# iso_country      object
# iso_region       object
# municipality     object
# gps_code         object
# iata_code        object
# local_code       object
# coordinates      object
# dtype: object

# %%
# Check Null values per column
((airport_data.isnull().sum()/airport_data.shape[0])*100).sort_values(ascending=False)
# Out:
# iata_code       83.315479
# continent       50.329551
# local_code      47.914662
# gps_code        25.501589
# elevation_ft    12.720835
# municipality    10.305946
# iso_country      0.448479
# coordinates      0.000000
# iso_region       0.000000
# name             0.000000
# type             0.000000
# ident            0.000000
# dtype: float64

# %%
# Drop columns not used
columns = ['iata_code', 'continent', 'gps_code', 'elevation_ft', 'local_code']
airport_data = airport_data.drop(columns=columns)

# %%
# Check Null values per column
((airport_data.isnull().sum()/airport_data.shape[0])*100).sort_values(ascending=False)
# Out:
# municipality    10.305946
# iso_country      0.448479
# coordinates      0.000000
# iso_region       0.000000
# name             0.000000
# type             0.000000
# ident            0.000000
# dtype: float64

# %%
airport_data.loc[(airport_data.iso_country.isnull())]
# Out:
#          ident            type                                       name  \
# 21422     FYAA   small_airport                             Ai-Ais Airport
# 21423     FYAB   small_airport                            Aroab B Airport
# 21424     FYAK   small_airport                         Aussenkehr Airport
# 21425     FYAM   small_airport                           Aminuis Airstrip
# 21426     FYAR  medium_airport                            Arandis Airport
# 21427     FYAS   small_airport                                Aus Airport
# 21428     FYAV   small_airport                         Ariamsvley Airport
# 21429     FYBC   small_airport                          Bethanien Airport
# 21430     FYBJ   small_airport  Bitterwasser Lodge & Flying Club Airfield
# 21431     FYEK   small_airport                            Epukiro Airport
# 21432     FYEN   small_airport                            Eenhana Airport
# 21433     FYGB   small_airport                            Gobabis Airport
# 21434     FYGC   small_airport                            Gochas Airstrip
# 21435     FYGF  medium_airport                       Grootfontein Airport
# 21436     FYGK   small_airport          Farm Whitwater East Landing Strip
# 21437     FYGL   small_airport                 Omaruru Game Lodge Airport
# 21438     FYGV   small_airport                    Gravenstein Prv Airport
# 21439     FYHH   small_airport                    Helmeringhausen Airport
# 21440     FYHI   small_airport                             Halali Airport
# 21441     FYHS   small_airport                              Hobas Airport
# 21442     FYIA   small_airport                    Intu Africa Pan Airport
# 21443     FYKA   small_airport                            Karibib Airport
# 21444     FYKB   small_airport                          Karasburg Airport
# 21445     FYKD   small_airport                           Kalkfeld Airport
# 21446     FYKE   small_airport                Kalahari Game Lodge Airport
# 21447     FYKJ   small_airport                           Kamanjab Airport
# 21448     FYKM   small_airport                      Katima Mulilo Airport
# 21449     FYKT  medium_airport                       Keetmanshoop Airport
# 21450     FYLS   small_airport                          Lianshulu Airport
# 21451     FYLZ  medium_airport                           Luderitz Airport
# ...        ...             ...                                        ...
# 35641  NA-0147   small_airport                   Steinhausen Landing Site
# 35642  NA-0148   small_airport                       Fortuna Landing Site
# 35643  NA-0149   small_airport                       Okamapu Landing Site
# 35644  NA-0150   small_airport                 Epukiro North Landing Site
# 35645  NA-0151   small_airport                            Epukiru Airport
# 35646  NA-0152   small_airport                    Onduruqea Lodge Airport
# 35647  NA-0153   small_airport                           Hochfeld Airport
# 35648  NA-0154   small_airport                      Godehoop Landing Site
# 35649  NA-0155   small_airport                        Rhenoster K Airport
# 35650  NA-0156   small_airport                         Omaha Landing Site
# 35651  NA-0157   small_airport                 Otjiwarongo Center Airport
# 35652  NA-0158   small_airport                            Isibis Airstrip
# 35653  NA-0159   small_airport                           Khorixas Airport
# 35654  NA-0160   small_airport                          Okongwati Airport
# 35655  NA-0161   small_airport                             Okongo Airport
# 35656  NA-0162   small_airport                            Kongola Airport
# 35657  NA-0163          closed                             Susuwe Airport
# 35658  NA-0164   small_airport                           Sikereti Airport
# 35659  NA-0165   small_airport                           Otjituuo Airport
# 35660  NA-0166   small_airport                          Okakarara Airport
# 35661  NA-0167   small_airport                                B8 Airstrip
# 35662  NA-0168   small_airport                            Palmwag Airport
# 35663  NA-0169   small_airport                             Ehomba Airport
# 35664  NA-0170   small_airport                        Uukwaluudhi Airport
# 35665  NA-0171   small_airport                             Outapi Airport
# 35666  NA-0172   small_airport                        Haklesdoorn Airport
# 35667  NA-0173   small_airport                     Ndonga Linena Airstrip
# 35668  NA-0174   small_airport                  Farm Etemba Landing Strip
# 35669  NA-0175   small_airport               Farm Dawib Ost Landing Strip
# 35670  NA-0176   small_airport                   Farm Gurus Landing Strip
#
#       iso_country iso_region            municipality  \
# 21422         NaN      NA-KU                  Ai-Ais
# 21423         NaN      NA-KA                   Aroab
# 21424         NaN      NA-KA              Aussenkehr
# 21425         NaN      NA-OH                 Aminuis
# 21426         NaN      NA-ER                 Arandis
# 21427         NaN      NA-KA                     Aus
# 21428         NaN      NA-KA              Ariamsvley
# 21429         NaN      NA-KA               Bethanien
# 21430         NaN      NA-HA            Bitterwasser
# 21431         NaN      NA-OH                 Epukiro
# 21432         NaN      NA-OW                 Eenhana
# 21433         NaN      NA-OH                 Gobabis
# 21434         NaN      NA-HA                  Gochas
# 21435         NaN      NA-OD            Grootfontein
# 21436         NaN      NA-HA        Desert Homestead
# 21437         NaN      NA-ER                 Omaruru
# 21438         NaN      NA-KH                     NaN
# 21439         NaN      NA-KA         Helmeringhausen
# 21440         NaN      NA-OT                  Halali
# 21441         NaN      NA-KA                   Hobas
# 21442         NaN      NA-HA                     NaN
# 21443         NaN      NA-ER                 Karibib
# 21444         NaN      NA-KA               Karasburg
# 21445         NaN      NA-OD                Kalkfeld
# 21446         NaN      NA-HA                     NaN
# 21447         NaN      NA-KU                Kamanjab
# 21448         NaN      NA-CA                  Mpacha
# 21449         NaN      NA-KA            Keetmanshoop
# 21450         NaN      NA-CA         Lianshulu Lodge
# 21451         NaN      NA-KA                Luderitz
# ...           ...        ...                     ...
# 35641         NaN      NA-OH             Steinhausen
# 35642         NaN      NA-OH                     NaN
# 35643         NaN      NA-OH                     NaN
# 35644         NaN      NA-OH                 Epukiro
# 35645         NaN      NA-OH                 Epukiro
# 35646         NaN      NA-ER                     NaN
# 35647         NaN      NA-OD                Hochfeld
# 35648         NaN      NA-ER                Okombahe
# 35649         NaN      NA-ER                     NaN
# 35650         NaN      NA-OD                     NaN
# 35651         NaN      NA-OD             Otjiwarongo
# 35652         NaN      NA-KH                  Isibis
# 35653         NaN      NA-KU                Khorixas
# 35654         NaN      NA-KU               Okongwati
# 35655         NaN      NA-OW                  Okongo
# 35656         NaN      NA-CA                 Kongola
# 35657         NaN      NA-CA                 Kongola
# 35658         NaN      NA-KE                Sikereti
# 35659         NaN      NA-OD                Otjituuo
# 35660         NaN      NA-OD               Okakarara
# 35661         NaN      NA-OD                     NaN
# 35662         NaN      NA-KU                 Palmwag
# 35663         NaN      NA-KU                  Ehomba
# 35664         NaN      NA-OS                     NaN
# 35665         NaN      NA-OS                  Outapi
# 35666         NaN      NA-KA             Haklesdoorn
# 35667         NaN      NA-KW                 Shitemo
# 35668         NaN      NA-ER  Etemba Wilderness Camp
# 35669         NaN      NA-ER        Hohenstein Lodge
# 35670         NaN      NA-HA                Kalkrand
#
#                                    coordinates
# 21422                         17.5966, -27.995
# 21423  19.633100509643555, -26.776100158691406
# 21424                        17.4645, -28.4587
# 21425  19.351699829101562, -23.655799865722656
# 21426  14.979999542236328, -22.462200164794922
# 21427  16.318899154663086, -26.693899154663086
# 21428  19.833900451660156, -28.118900299072266
# 21429                        17.1816, -26.5448
# 21430                   17.9911003113, -23.875
# 21431   19.10610008239746, -21.786699295043945
# 21432   16.32200050354004, -17.482999801635742
# 21433    18.973100662231445, -22.5044002532959
# 21434  18.817800521850586, -24.856399536132812
# 21435   18.122699737548828, -19.60219955444336
# 21436                      15.9392, -24.629999
# 21437  16.089399337768555, -21.326099395751953
# 21438  17.497800827026367, -23.458900451660156
# 21439  16.809999465942383, -25.863300323486328
# 21440                        16.4585, -19.0285
# 21441  17.693300247192383, -27.624399185180664
# 21442   17.95170021057129, -24.088300704956055
# 21443   15.902799606323242, -21.84779930114746
# 21444                        18.7385, -28.0297
# 21445  16.207799911499023, -20.901399612426758
# 21446   19.87809944152832, -25.651100158691406
# 21447    14.8233003616333, -19.520599365234375
# 21448                    24.176701, -17.634399
# 21449    18.111400604248047, -26.5398006439209
# 21450  23.393299102800004, -18.116699218799997
# 21451  15.242899894714355, -26.687400817871094
# ...                                        ...
# 35641   18.231950759887695, -21.82444953918457
# 35642   19.90833282470703, -21.808332443237305
# 35643  17.885000228881836, -21.736949920654297
# 35644    19.21693229675293, -21.67526626586914
# 35645  19.399999618530273, -21.616666793823242
# 35646  16.073299407958984, -21.602500915527344
# 35647    17.85194969177246, -21.49028205871582
# 35648   15.533332824707031, -21.28333282470703
# 35649      16.40250015258789, -21.165283203125
# 35650     16.5261173248291, -21.13195037841797
# 35651  16.647783279418945, -20.463882446289062
# 35652                        16.5075, -23.4178
# 35653                    15.059298, -20.366192
# 35654                       13.2782, -17.43873
# 35655                    17.225298, -17.565947
# 35656                    23.307089, -17.775197
# 35657                    23.278472, -17.775984
# 35658                    20.698375, -19.104117
# 35659                    18.558635, -19.652406
# 35660                    17.468807, -20.601996
# 35661                    18.664579, -19.059552
# 35662                    13.943931, -19.873201
# 35663                       13.836836, -17.488
# 35664                    14.410431, -18.109282
# 35665                    15.007946, -17.574847
# 35666                    18.239166, -28.886092
# 35667                     20.534708, -17.98345
# 35668                    15.606778, -21.405111
# 35669                    15.515361, -21.774528
# 35670                     17.610417, -24.07675
#
# [247 rows x 7 columns]

# %%
mask = (airport_data.iso_country.isnull()) & (airport_data.iso_region.str[:2] == 'NA')

airport_data.loc[mask, 'iso_country'] = 'NA'

# %%
((airport_data.isnull().sum()/airport_data.shape[0])*100).sort_values(ascending=False)
# Out:
# municipality    10.305946
# coordinates      0.000000
# iso_region       0.000000
# iso_country      0.000000
# name             0.000000
# type             0.000000
# ident            0.000000
# dtype: float64

# %%
airport_data.duplicated().sum()
# Out:
# 0

# %%
airport_data.dropna(axis=0, inplace=True)

# %%
airport_data.shape
# Out:
# (49399, 7)

# %% [markdown]
# - **Demographic Data**

# %%
demo.shape
# Out:
# (2891, 12)

# %%
# Check data types
demo.dtypes
# Out:
# City                       object
# State                      object
# Median Age                float64
# Male Population           float64
# Female Population         float64
# Total Population            int64
# Number of Veterans        float64
# Foreign-born              float64
# Average Household Size    float64
# State Code                 object
# Race                       object
# Count                       int64
# dtype: object

# %%
# Check Null values per column
((demo.isnull().sum()/demo.shape[0])*100).sort_values(ascending=False)
# Out:
# Average Household Size    0.553442
# Foreign-born              0.449671
# Number of Veterans        0.449671
# Female Population         0.103770
# Male Population           0.103770
# Count                     0.000000
# Race                      0.000000
# State Code                0.000000
# Total Population          0.000000
# Median Age                0.000000
# State                     0.000000
# City                      0.000000
# dtype: float64

# %%
demo = demo.drop(columns='Number of Veterans')
demo.head()
# Out:
#                City          State  Median Age  Male Population  \
# 0     Silver Spring       Maryland        33.8          40601.0
# 1            Quincy  Massachusetts        41.0          44129.0
# 2            Hoover        Alabama        38.5          38040.0
# 3  Rancho Cucamonga     California        34.5          88127.0
# 4            Newark     New Jersey        34.6         138040.0
#
#    Female Population  Total Population  Foreign-born  Average Household Size  \
# 0            41862.0             82463       30908.0                    2.60
# 1            49500.0             93629       32935.0                    2.39
# 2            46799.0             84839        8229.0                    2.58
# 3            87105.0            175232       33878.0                    3.18
# 4           143873.0            281913       86253.0                    2.73
#
#   State Code                       Race  Count
# 0         MD         Hispanic or Latino  25924
# 1         MA                      White  58723
# 2         AL                      Asian   4759
# 3         CA  Black or African-American  24437
# 4         NJ                      White  76402

# %%
demo.loc[(demo.City=='Portland')]
# Out:
#           City   State  Median Age  Male Population  Female Population  \
# 530   Portland   Maine        40.3          31480.0            35392.0
# 943   Portland  Oregon        36.7         313516.0           318671.0
# 1962  Portland   Maine        40.3          31480.0            35392.0
# 2534  Portland  Oregon        36.7         313516.0           318671.0
# 2535  Portland   Maine        40.3          31480.0            35392.0
# 2724  Portland  Oregon        36.7         313516.0           318671.0
# 2793  Portland  Oregon        36.7         313516.0           318671.0
# 2794  Portland   Maine        40.3          31480.0            35392.0
# 2795  Portland   Maine        40.3          31480.0            35392.0
# 2831  Portland  Oregon        36.7         313516.0           318671.0
#
#       Total Population  Number of Veterans  Foreign-born  \
# 530              66872              3666.0        9229.0
# 943             632187             29940.0       86041.0
# 1962             66872              3666.0        9229.0
# 2534            632187             29940.0       86041.0
# 2535             66872              3666.0        9229.0
# 2724            632187             29940.0       86041.0
# 2793            632187             29940.0       86041.0
# 2794             66872              3666.0        9229.0
# 2795             66872              3666.0        9229.0
# 2831            632187             29940.0       86041.0
#
#       Average Household Size State Code                               Race  \
# 530                     2.13         ME                              White
# 943                     2.43         OR  American Indian and Alaska Native
# 1962                    2.13         ME          Black or African-American
# 2534                    2.43         OR                              White
# 2535                    2.13         ME                              Asian
# 2724                    2.43         OR                              Asian
# 2793                    2.43         OR                 Hispanic or Latino
# 2794                    2.13         ME                 Hispanic or Latino
# 2795                    2.13         ME  American Indian and Alaska Native
# 2831                    2.43         OR          Black or African-American
#
#        Count
# 530    59722
# 943    15314
# 1962    5750
# 2534  524258
# 2535    3696
# 2724   64386
# 2793   61064
# 2794    2031
# 2795     662
# 2831   45914

# %%
demo.loc[(demo['Female Population'].isnull() | demo['Male Population'].isnull())]
# Out:
#               City    State  Median Age  Male Population  Female Population  \
# 333   The Villages  Florida        70.5              NaN                NaN
# 449   The Villages  Florida        70.5              NaN                NaN
# 1437  The Villages  Florida        70.5              NaN                NaN
#
#       Total Population  Foreign-born  Average Household Size State Code  \
# 333              72590        4034.0                     NaN         FL
# 449              72590        4034.0                     NaN         FL
# 1437             72590        4034.0                     NaN         FL
#
#                            Race  Count
# 333          Hispanic or Latino   1066
# 449   Black or African-American    331
# 1437                      White  72211

# %%
demo.loc[(demo['Foreign-born'].isnull() | demo['Average Household Size'].isnull())]
# Out:
#               City        State  Median Age  Male Population  \
# 111       San Juan  Puerto Rico        41.4         155408.0
# 155         Caguas  Puerto Rico        40.4          34743.0
# 258       Carolina  Puerto Rico        42.0          64758.0
# 333   The Villages      Florida        70.5              NaN
# 449   The Villages      Florida        70.5              NaN
# 637       Carolina  Puerto Rico        42.0          64758.0
# 1437  The Villages      Florida        70.5              NaN
# 1747      San Juan  Puerto Rico        41.4         155408.0
# 1748      Mayagüez  Puerto Rico        38.1          30799.0
# 1995         Ponce  Puerto Rico        40.5          56968.0
# 2004       Bayamón  Puerto Rico        39.4          80128.0
# 2441      San Juan  Puerto Rico        41.4         155408.0
# 2589      Guaynabo  Puerto Rico        42.2          33066.0
# 2597        Caguas  Puerto Rico        40.4          34743.0
# 2654      Guaynabo  Puerto Rico        42.2          33066.0
# 2746      Mayagüez  Puerto Rico        38.1          30799.0
#
#       Female Population  Total Population  Foreign-born  \
# 111            186829.0            342237           NaN
# 155             42265.0             77008           NaN
# 258             77308.0            142066           NaN
# 333                 NaN             72590        4034.0
# 449                 NaN             72590        4034.0
# 637             77308.0            142066           NaN
# 1437                NaN             72590        4034.0
# 1747           186829.0            342237           NaN
# 1748            35782.0             66581           NaN
# 1995            64615.0            121583           NaN
# 2004            90131.0            170259           NaN
# 2441           186829.0            342237           NaN
# 2589            37426.0             70492           NaN
# 2597            42265.0             77008           NaN
# 2654            37426.0             70492           NaN
# 2746            35782.0             66581           NaN
#
#       Average Household Size State Code                               Race  \
# 111                      NaN         PR                 Hispanic or Latino
# 155                      NaN         PR                 Hispanic or Latino
# 258                      NaN         PR  American Indian and Alaska Native
# 333                      NaN         FL                 Hispanic or Latino
# 449                      NaN         FL          Black or African-American
# 637                      NaN         PR                 Hispanic or Latino
# 1437                     NaN         FL                              White
# 1747                     NaN         PR  American Indian and Alaska Native
# 1748                     NaN         PR                              Asian
# 1995                     NaN         PR                 Hispanic or Latino
# 2004                     NaN         PR                 Hispanic or Latino
# 2441                     NaN         PR                              Asian
# 2589                     NaN         PR                 Hispanic or Latino
# 2597                     NaN         PR  American Indian and Alaska Native
# 2654                     NaN         PR  American Indian and Alaska Native
# 2746                     NaN         PR                 Hispanic or Latino
#
#        Count
# 111   335559
# 155    76349
# 258    12143
# 333     1066
# 449      331
# 637   139967
# 1437   72211
# 1747    4031
# 1748     235
# 1995  120705
# 2004  169155
# 2441    2452
# 2589   69936
# 2597     624
# 2654     589
# 2746   65521

# %%
demo.dropna(axis=0, inplace=True)

# %%
demo.duplicated().sum()
# Out:
# 0

# %%
demo.shape
# Out:
# (2891, 11)

# %%
demo.columns = [col.lower().replace(' ', '_').replace('-', '_') for col in demo.columns]

# %%
demo.head()
# Out:
#                city          state  median_age  male_population  \
# 0     Silver Spring       Maryland        33.8          40601.0
# 1            Quincy  Massachusetts        41.0          44129.0
# 2            Hoover        Alabama        38.5          38040.0
# 3  Rancho Cucamonga     California        34.5          88127.0
# 4            Newark     New Jersey        34.6         138040.0
#
#    female_population  total_population  foreign_born  average_household_size  \
# 0            41862.0             82463       30908.0                    2.60
# 1            49500.0             93629       32935.0                    2.39
# 2            46799.0             84839        8229.0                    2.58
# 3            87105.0            175232       33878.0                    3.18
# 4           143873.0            281913       86253.0                    2.73
#
#   state_code                       race  count
# 0         MD         Hispanic or Latino  25924
# 1         MA                      White  58723
# 2         AL                      Asian   4759
# 3         CA  Black or African-American  24437
# 4         NJ                      White  76402

# %%
demo['city'] = demo['city'].str.upper()
demo['state'] = demo['state'].str.upper()
demo.head(5)
# Out:
#                city          state  median_age  male_population  \
# 0     SILVER SPRING       MARYLAND        33.8          40601.0
# 1            QUINCY  MASSACHUSETTS        41.0          44129.0
# 2            HOOVER        ALABAMA        38.5          38040.0
# 3  RANCHO CUCAMONGA     CALIFORNIA        34.5          88127.0
# 4            NEWARK     NEW JERSEY        34.6         138040.0
#
#    female_population  total_population  foreign_born  average_household_size  \
# 0            41862.0             82463       30908.0                    2.60
# 1            49500.0             93629       32935.0                    2.39
# 2            46799.0             84839        8229.0                    2.58
# 3            87105.0            175232       33878.0                    3.18
# 4           143873.0            281913       86253.0                    2.73
#
#   state_code                       race  count
# 0         MD         Hispanic or Latino  25924
# 1         MA                      White  58723
# 2         AL                      Asian   4759
# 3         CA  Black or African-American  24437
# 4         NJ                      White  76402

# %% [markdown]
# - **Temperature Data**

# %%
temp.shape
# Out:
# (8599212, 7)

# %%
temp.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# City                              object
# Country                           object
# Latitude                          object
# Longitude                         object
# dtype: object

# %%
((temp.isnull().sum()/temp.shape[0])*100).sort_values(ascending=False)
# Out:
# AverageTemperatureUncertainty    4.234458
# AverageTemperature               4.234458
# Longitude                        0.000000
# Latitude                         0.000000
# Country                          0.000000
# City                             0.000000
# dt                               0.000000
# dtype: float64

# %%
print(f'Min. DT: {temp.dt.min()}')
print(f'Max. DT: {temp.dt.max()}')
# Out:
# Min. DT: 1743-11-01
# Max. DT: 2013-09-01

# %%
# Create a tempora slice of 5 years
lower_dt = '2008-01-01'
temp = temp.loc[temp.dt >= lower_dt]

# %%
((temp.isnull().sum()/temp.shape[0])*100).sort_values(ascending=False)
# Out:
# AverageTemperatureUncertainty    1.2676
# AverageTemperature               1.2676
# Longitude                        0.0000
# Latitude                         0.0000
# Country                          0.0000
# City                             0.0000
# dt                               0.0000
# dtype: float64

# %%
temp.loc[temp.AverageTemperature.isnull()]
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 3238     2013-09-01                 NaN                            NaN
# 6477     2013-09-01                 NaN                            NaN
# 9606     2013-09-01                 NaN                            NaN
# 11924    2013-09-01                 NaN                            NaN
# 14242    2013-09-01                 NaN                            NaN
# 17481    2013-09-01                 NaN                            NaN
# 20720    2013-09-01                 NaN                            NaN
# 23959    2013-09-01                 NaN                            NaN
# 25852    2013-09-01                 NaN                            NaN
# 28170    2013-09-01                 NaN                            NaN
# 30063    2013-09-01                 NaN                            NaN
# 32381    2013-09-01                 NaN                            NaN
# 36587    2013-09-01                 NaN                            NaN
# 38480    2013-09-01                 NaN                            NaN
# 41719    2013-09-01                 NaN                            NaN
# 43552    2013-09-01                 NaN                            NaN
# 45529    2013-09-01                 NaN                            NaN
# 47554    2013-09-01                 NaN                            NaN
# 52250    2013-09-01                 NaN                            NaN
# 54227    2013-09-01                 NaN                            NaN
# 56276    2013-09-01                 NaN                            NaN
# 58169    2013-09-01                 NaN                            NaN
# 62493    2013-09-01                 NaN                            NaN
# 64470    2013-09-01                 NaN                            NaN
# 67083    2013-09-01                 NaN                            NaN
# 69401    2013-09-01                 NaN                            NaN
# 71719    2013-09-01                 NaN                            NaN
# 76672    2013-09-01                 NaN                            NaN
# 78637    2013-09-01                 NaN                            NaN
# 80710    2013-09-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 8527915  2013-09-01                 NaN                            NaN
# 8530286  2013-09-01                 NaN                            NaN
# 8532359  2013-09-01                 NaN                            NaN
# 8534432  2013-09-01                 NaN                            NaN
# 8536853  2013-09-01                 NaN                            NaN
# 8538935  2013-09-01                 NaN                            NaN
# 8541020  2013-09-01                 NaN                            NaN
# 8543391  2013-09-01                 NaN                            NaN
# 8545476  2013-09-01                 NaN                            NaN
# 8547549  2013-09-01                 NaN                            NaN
# 8549622  2013-09-01                 NaN                            NaN
# 8551707  2013-09-01                 NaN                            NaN
# 8553780  2013-09-01                 NaN                            NaN
# 8557019  2013-09-01                 NaN                            NaN
# 8559092  2013-09-01                 NaN                            NaN
# 8561410  2013-09-01                 NaN                            NaN
# 8563483  2013-09-01                 NaN                            NaN
# 8566722  2013-09-01                 NaN                            NaN
# 8569961  2013-09-01                 NaN                            NaN
# 8572279  2013-09-01                 NaN                            NaN
# 8574256  2013-09-01                 NaN                            NaN
# 8576149  2013-09-01                 NaN                            NaN
# 8578956  2013-09-01                 NaN                            NaN
# 8582195  2013-09-01                 NaN                            NaN
# 8585434  2013-09-01                 NaN                            NaN
# 8587519  2013-09-01                 NaN                            NaN
# 8589604  2013-09-01                 NaN                            NaN
# 8592843  2013-09-01                 NaN                            NaN
# 8595972  2013-09-01                 NaN                            NaN
# 8599211  2013-09-01                 NaN                            NaN
#
#                   City               Country Latitude Longitude
# 3238             Århus               Denmark   57.05N    10.33E
# 6477             Çorlu                Turkey   40.99N    27.69E
# 9606             Çorum                Turkey   40.99N    34.08E
# 11924          Öskemen            Kazakhstan   50.63N    82.39E
# 14242           Ürümqi                 China   44.20N    87.20E
# 17481         A Coruña                 Spain   42.59N     8.73W
# 20720           Aachen               Germany   50.63N     6.34E
# 23959          Aalborg               Denmark   57.05N    10.33E
# 25852              Aba               Nigeria    5.63N     8.07E
# 28170           Abadan                  Iran   29.74N    48.00E
# 30063        Abakaliki               Nigeria    5.63N     8.07E
# 32381           Abakan                Russia   53.84N    91.36E
# 36587       Abengourou         Côte D'Ivoire    7.23N     4.05W
# 38480         Abeokuta               Nigeria    7.23N     4.05E
# 41719         Aberdeen        United Kingdom   57.05N     1.48W
# 43552             Abha          Saudi Arabia   18.48N    42.25E
# 45529          Abidjan         Côte D'Ivoire    5.63N     3.23W
# 47554            Abiko                 Japan   36.17N   139.23E
# 52250           Abohar                 India   29.74N    73.85E
# 54227    Abomey Calavi                 Benin    7.23N     2.43E
# 56276        Abu Dhabi  United Arab Emirates   24.92N    54.98E
# 58169            Abuja               Nigeria    8.84N     7.30E
# 62493         Acarigua             Venezuela    8.84N    68.92W
# 64470            Accra                 Ghana    5.63N     0.00W
# 67083         Achalpur                 India   21.70N    77.02E
# 69401           Acheng                 China   45.81N   128.08E
# 71719          Achinsk                Russia   57.05N    90.00E
# 76672            Adana                Turkey   36.17N    35.80E
# 78637      Addis Abeba              Ethiopia    8.84N    38.11E
# 80710         Adelaide             Australia   34.56S   138.16E
# ...                ...                   ...      ...       ...
# 8527915       Zhaoqing                 China   23.31N   112.72E
# 8530286       Zhaotong                 China   26.52N   103.88E
# 8532359       Zhaoyang                 China   32.95N   119.68E
# 8534432      Zhenjiang                 China   32.95N   119.68E
# 8536853     Zhezkazgan            Kazakhstan   47.42N    67.50E
# 8538935       Zhicheng                 China   29.74N   110.77E
# 8541020      Zhongshan                 China   21.70N   113.37E
# 8543391      Zhoucheng                 China   24.92N   102.86E
# 8545476        Zhoucun                 China   36.17N   117.35E
# 8547549        Zhoukou                 China   32.95N   113.94E
# 8549622       Zhucheng                 China   36.17N   119.34E
# 8551707         Zhuhai                 China   21.70N   113.37E
# 8553780          Zhuji                 China   29.74N   120.00E
# 8557019     Zhukovskiy                Russia   55.45N    36.85E
# 8559092      Zhumadian                 China   32.95N   113.94E
# 8561410       Zhuozhou                 China   39.38N   116.53E
# 8563483        Zhuzhou                 China   28.13N   113.64E
# 8566722       Zhytomyr               Ukraine   50.63N    29.15E
# 8569961   Zielona Gora                Poland   52.24N    15.77E
# 8572279         Zigong                 China   29.74N   105.23E
# 8574256     Ziguinchor               Senegal   12.05N    16.44W
# 8576149         Zinder                 Niger   13.66N     9.08E
# 8578956       Zlatoust                Russia   55.45N    59.53E
# 8582195     Zoetermeer           Netherlands   52.24N     5.26E
# 8585434      Zonguldak                Turkey   40.99N    31.95E
# 8587519        Zouxian                 China   36.17N   117.35E
# 8589604          Zunyi                 China   28.13N   106.36E
# 8592843         Zurich           Switzerland   47.42N     8.29E
# 8595972        Zuwarah                 Libya   32.95N    12.45E
# 8599211         Zwolle           Netherlands   52.24N     5.26E
#
# [3070 rows x 7 columns]

# %%
temp = temp.dropna(axis=0)

# %%
temp.shape
# Out:
# (239120, 7)

# %%
temp.columns = [''.join(['_' + c.lower() if c.isupper() else c for c in col]).lstrip('_') for col in temp.columns]

# %%
temp['city'] = temp['city'].str.upper()
temp.head(5)
# Out:
#               dt  average_temperature  average_temperature_uncertainty   city  \
# 3170  2008-01-01                3.953                            0.383  ÅRHUS
# 3171  2008-02-01                4.925                            0.363  ÅRHUS
# 3172  2008-03-01                3.654                            0.172  ÅRHUS
# 3173  2008-04-01                7.758                            0.195  ÅRHUS
# 3174  2008-05-01               13.243                            0.220  ÅRHUS
#
#       country latitude longitude
# 3170  Denmark   57.05N    10.33E
# 3171  Denmark   57.05N    10.33E
# 3172  Denmark   57.05N    10.33E
# 3173  Denmark   57.05N    10.33E
# 3174  Denmark   57.05N    10.33E

# %% [markdown]
# - **Immigration Events**

# %%
immigration_data.shape
# Out:
# (3096313, 28)

# %%
# Select relevant columns for this project purpose
immigration = immigration_data[[
    'cicid', 'i94yr', 'i94mon', 'i94res', 'i94port',
    'arrdate', 'i94mode', 'i94addr', 'depdate', 'i94bir', 'i94visa',
    'gender'
]]

# %%
immigration.head(5)
# Out:
#    cicid   i94yr  i94mon  i94res i94port  arrdate  i94mode i94addr  depdate  \
# 0    6.0  2016.0     4.0   692.0     XXX  20573.0      NaN     NaN      NaN
# 1    7.0  2016.0     4.0   276.0     ATL  20551.0      1.0      AL      NaN
# 2   15.0  2016.0     4.0   101.0     WAS  20545.0      1.0      MI  20691.0
# 3   16.0  2016.0     4.0   101.0     NYC  20545.0      1.0      MA  20567.0
# 4   17.0  2016.0     4.0   101.0     NYC  20545.0      1.0      MA  20567.0
#
#    i94bir  i94visa   dtaddto gender airline visatype
# 0    37.0      2.0  10282016    NaN     NaN       B2
# 1    25.0      3.0       D/S      M     NaN       F1
# 2    55.0      2.0  09302016      M      OS       B2
# 3    28.0      2.0  09302016    NaN      AA       B2
# 4     4.0      2.0  09302016    NaN      AA       B2

# %%
immigration.dtypes
# Out:
# cicid       float64
# i94yr       float64
# i94mon      float64
# i94res      float64
# i94port      object
# arrdate     float64
# i94mode     float64
# i94addr      object
# depdate     float64
# i94bir      float64
# i94visa     float64
# dtaddto      object
# gender       object
# airline      object
# visatype     object
# dtype: object

# %%
print(f'Max yr: {immigration.i94yr.max()}')
print(f'Min yr: {immigration.i94yr.min()}')
print(f'Max mon: {immigration.i94mon.max()}')
print(f'Min mon: {immigration.i94mon.min()}')
# Out:
# Max yr: 2016.0
# Min yr: 2016.0
# Max mon: 4.0
# Min mon: 4.0

# %%
((immigration.isnull().sum()/immigration.shape[0])*100).sort_values(ascending=False)
# Out:
# gender      13.379429
# i94addr      4.921079
# depdate      4.600859
# airline      2.700857
# i94bir       0.025902
# dtaddto      0.015405
# i94mode      0.007719
# visatype     0.000000
# i94visa      0.000000
# arrdate      0.000000
# i94port      0.000000
# i94res       0.000000
# i94mon       0.000000
# i94yr        0.000000
# cicid        0.000000
# dtype: float64

# %%
immigration.head()
# Out:
#    cicid   i94yr  i94mon  i94res i94port  arrdate  i94mode i94addr  depdate  \
# 0    6.0  2016.0     4.0   692.0     XXX  20573.0      NaN     NaN      NaN
# 1    7.0  2016.0     4.0   276.0     ATL  20551.0      1.0      AL      NaN
# 2   15.0  2016.0     4.0   101.0     WAS  20545.0      1.0      MI  20691.0
# 3   16.0  2016.0     4.0   101.0     NYC  20545.0      1.0      MA  20567.0
# 4   17.0  2016.0     4.0   101.0     NYC  20545.0      1.0      MA  20567.0
#
#    i94bir  i94visa   dtaddto gender airline visatype
# 0    37.0      2.0  10282016    NaN     NaN       B2
# 1    25.0      3.0       D/S      M     NaN       F1
# 2    55.0      2.0  09302016      M      OS       B2
# 3    28.0      2.0  09302016    NaN      AA       B2
# 4     4.0      2.0  09302016    NaN      AA       B2

# %%
immigration.shape
# Out:
# (3096313, 15)

# %% [markdown]
# #### Parse description file to get auxiliary information

# %%
with open("raw_data/I94_SAS_Labels_Descriptions.SAS") as f:
    contents = f.readlines()

# %%
country_code = {}
for countries in contents[10:298]:
    pair = countries.split('=')
    code, country = pair[0].strip(), pair[1].strip().strip("'")
    country_code[code] = country

# %%
country_data = pd.DataFrame(list(country_code.items()), columns=['code', 'country'])
country_data.head(5)
# Out:
#   code      country
# 0  236  AFGHANISTAN
# 1  101      ALBANIA
# 2  316      ALGERIA
# 3  102      ANDORRA
# 4  324       ANGOLA

# %%
city_code = {}
for cities in contents[303:962]:
    pair = cities.split('=')
    code, city = pair[0].strip("\t").strip().strip("'"), pair[1].strip('\t').strip().strip("''")
    city_code[code] = city

# %%
city_data = pd.DataFrame(list(city_code.items()), columns=['code', 'city'])
city_data.head(5)
# Out:
#   code                          city
# 0  ANC        ANCHORAGE, AK
# 1  BAR  BAKER AAF - BAKER ISLAND, AK
# 2  DAC        DALTONS CACHE, AK
# 3  PIZ    DEW STATION PT LAY DEW, AK
# 4  DTH        DUTCH HARBOR, AK

# %%
state_code = {}
for states in contents[982:1036]:
    pair = states.split('=')
    code, state = pair[0].strip('\t').strip("'"), pair[1].strip().strip("'")
    state_code[code] = state

# %%
state_data = pd.DataFrame(list(state_code.items()), columns=['code', 'state'])
state_data.head(5)
# Out:
#   code       state
# 0   AK      ALASKA
# 1   AZ     ARIZONA
# 2   AR    ARKANSAS
# 3   CA  CALIFORNIA
# 4   CO    COLORADO

# %% [markdown]
# ### Step 3: Define the Data Model
# #### 3.1 Conceptual Data Model
# Map out the conceptual data model and explain why you chose that model
#
# - Multidimensional Model
# ![title](img/dend-udacity.png)

# %% [markdown]
# #### 3.2 Mapping Out Data Pipelines
# List the steps necessary to pipeline the data into the chosen data model
#
# - Select relevant features to construct immigration_fact based on I94 raw data
#     - clean up incorrect or missing data
#     - convert arrdate and depdate into standard/readable DATE format
# - Create Dimension tables
#     - dim_demo (Based on demographics data)
#     - dim_mode (Based on auxiliary data provided)
#     - dim_visa (Based on visa data)
#     - dim_country (Based on auxiliary date provided)
#     - dim_port (Based on auxiliary data provided)
# - Write Dimension tables into Parquet format
# - Write Fact table into Parquet format

# %% [markdown]
# ### Step 4: Run Pipelines to Model the Data
# #### 4.1 Create the data model
# Build the data pipelines to create the data model.

# %% [markdown]
# ### Read Data With Spark

# %%
spark = SparkSession.builder.\
config("spark.jars.repositories", "https://repos.spark-packages.org/").\
config("spark.jars.packages", "saurfang:spark-sas7bdat:2.0.0-s_2.11").\
enableHiveSupport().getOrCreate()

#df_spark = spark.read.format('com.github.saurfang.sas.spark').load('../../data/18-83510-I94-Data-2016/i94_apr16_sub.sas7bdat')

# %%
df_spark=spark.read.parquet("raw_data/sas_data")

# %%
immigration_fact = df_spark.select(
    'cicid', 'i94yr', 'i94mon', 'i94res', 'i94port',
    'arrdate', 'depdate', 'i94mode', 'i94bir', 'i94visa', 'gender'
)

# %%
immigration_fact = immigration_fact.withColumn('arrdate', F.expr("date_add(to_date('1960-01-01'), int(arrdate))"))

# %%
immigration_fact = immigration_fact.withColumn('depdate', F.expr("date_add(to_date('1960-01-01'), int(depdate))"))

# %%
immigration_fact.show(5)
# Out:
# +---------+------+------+------+-------+----------+----------+-------+------+-------+------+
# |    cicid| i94yr|i94mon|i94res|i94port|   arrdate|   depdate|i94mode|i94bir|i94visa|gender|
# +---------+------+------+------+-------+----------+----------+-------+------+-------+------+
# |5748517.0|2016.0|   4.0| 438.0|    LOS|2016-04-30|2016-05-08|    1.0|  40.0|    1.0|     F|
# |5748518.0|2016.0|   4.0| 438.0|    LOS|2016-04-30|2016-05-17|    1.0|  32.0|    1.0|     F|
# |5748519.0|2016.0|   4.0| 438.0|    LOS|2016-04-30|2016-05-08|    1.0|  29.0|    1.0|     M|
# |5748520.0|2016.0|   4.0| 438.0|    LOS|2016-04-30|2016-05-14|    1.0|  29.0|    1.0|     F|
# |5748521.0|2016.0|   4.0| 438.0|    LOS|2016-04-30|2016-05-14|    1.0|  28.0|    1.0|     M|
# +---------+------+------+------+-------+----------+----------+-------+------+-------+------+
# only showing top 5 rows

# %%
immigration_fact = immigration_fact.withColumn("cicid", F.col("cicid").cast(IntegerType())) \
                                        .withColumn("i94yr", F.col("i94yr").cast(IntegerType())) \
                                        .withColumn("i94mon", F.col("i94mon").cast(IntegerType())) \
                                        .withColumn("i94res", F.col("i94res").cast(IntegerType())) \
                                        .withColumn("i94mode", F.col("i94mode").cast(IntegerType())) \
                                        .withColumn("i94bir", F.col("i94bir").cast(IntegerType())) \
                                        .withColumn("i94visa", F.col("i94visa").cast(IntegerType()))

# %%
#write to parquet
immigration_fact.write.mode('overwrite').partitionBy('i94yr', 'i94mon').parquet("immigration_fact")

# %%
df_spark = spark.read.options(delimiter=';').csv('raw_data/us-cities-demographics.csv', header=True)

# %%
columns = df_spark.columns
new_columns = [col.lower().replace(' ', '_').replace('-', '_') for col in columns]
dim_demo = df_spark.toDF(*new_columns)

# %%
dim_demo = dim_demo.select(
    'city', 'state_code', 'median_age', 'male_population', 'female_population',
    'total_population', 'foreign_born', 'average_household_size'
)

# %%
dim_demo = dim_demo.withColumn('city', F.upper(F.col('city')))

# %%
dim_demo = dim_demo.withColumn('city_state', F.concat_ws('-',dim_demo.city,dim_demo.state_code))

# %%
dim_demo = dim_demo.select(
    'city_state', 'city', 'state_code', 'median_age', 
    'male_population', 'female_population',
    'total_population', 'foreign_born', 'average_household_size'
)

# %%
dim_demo = dim_demo.dropDuplicates()

# %%
dim_demo.show(5)
# Out:
# +----------------+-------------+----------+----------+---------------+-----------------+----------------+------------+----------------------+
# |      city_state|         city|state_code|median_age|male_population|female_population|total_population|foreign_born|average_household_size|
# +----------------+-------------+----------+----------+---------------+-----------------+----------------+------------+----------------------+
# |        ALLEN-PA|        ALLEN|        PA|      33.5|          60626|            59581|          120207|       19652|                  2.67|
# |     SYRACUSE-NY|     SYRACUSE|        NY|      30.3|          69462|            74690|          144152|       17733|                  2.39|
# |        OGDEN-UT|        OGDEN|        UT|      31.3|          44323|            41127|           85450|       12791|                  2.68|
# |BROOKLYN PARK-MN|BROOKLYN PARK|        MN|      35.1|          37845|            41305|           79150|       17490|                  2.85|
# |  EAST ORANGE-NJ|  EAST ORANGE|        NJ|      35.5|          29995|            34967|           64962|       15164|                  2.85|
# +----------------+-------------+----------+----------+---------------+-----------------+----------------+------------+----------------------+
# only showing top 5 rows

# %%
dim_demo.write.mode("overwrite").parquet("dim_demo")

# %%
df_spark = spark.read.options(delimiter=',').csv('raw_data/airport-codes_csv.csv', header=True)

# %%
dim_port = df_spark.filter(F.col('iso_country')=='US')

# %%
dim_port = dim_port.select('ident', 'iso_region', 'municipality')

# %%
dim_port = dim_port.withColumn('state', F.split(dim_port.iso_region, '-')[1])

# %%
dim_port = dim_port.drop('iso_region')

# %%
columns = ['port_code', 'city', 'state']
dim_port = dim_port.toDF(*columns)

# %%
dim_port = dim_port.withColumn('city', F.upper(dim_port.city))

# %%
dim_port = dim_port.withColumn('city_state', F.concat_ws('-', dim_port.city, dim_port.state))

# %%
dim_port.show(2)
# Out:
# +---------+--------+-----+-----------+
# |port_code|    city|state| city_state|
# +---------+--------+-----+-----------+
# |      00A|BENSALEM|   PA|BENSALEM-PA|
# |     00AA|   LEOTI|   KS|   LEOTI-KS|
# +---------+--------+-----+-----------+
# only showing top 2 rows

# %%
dim_port.write.mode("overwrite").parquet("dim_port")

# %%
visa_data = [
    {'visa_code': 1, 'visa_type': 'Business'},
    {'visa_code': 2, 'visa_type': 'Pleasure'},
    {'visa_code': 3, 'visa_type': 'Student'}
]

dim_visa = spark.createDataFrame(Row(**x) for x in visa_data)

# %%
dim_visa.show()
# Out:
# +---------+---------+
# |visa_code|visa_type|
# +---------+---------+
# |        1| Business|
# |        2| Pleasure|
# |        3|  Student|
# +---------+---------+

# %%
dim_visa.write.mode("overwrite").parquet('dim_visa')

# %%
with open("raw_data/I94_SAS_Labels_Descriptions.SAS") as f:
    contents = f.readlines()
    
countries = {}
for countrie in contents[10:298]:
    pair = countrie.split('=')
    country_code, country = pair[0].strip(), pair[1].strip().strip("'")
    countries[country_code] = country

dim_country = spark.createDataFrame(countries.items(), ['country_code', 'country'])

# %%
dim_country.show(5)
# Out:
# +------------+-----------+
# |country_code|    country|
# +------------+-----------+
# |         236|AFGHANISTAN|
# |         101|    ALBANIA|
# |         316|    ALGERIA|
# |         102|    ANDORRA|
# |         324|     ANGOLA|
# +------------+-----------+
# only showing top 5 rows

# %%
dim_country.write.mode("overwrite").parquet('dim_country')

# %%
modes = {}
for mode in contents[973:976]:
    pair = mode.split('=')
    mode_id, mode_type = pair[0].strip(), pair[1].strip().strip("'").strip(";").strip("' ")
    modes[mode_id] = mode_type

dim_mode = spark.createDataFrame(modes.items(), ['mode_id', 'mode_type'])

# %%
dim_mode.show()
# Out:
# +-------+------------+
# |mode_id|   mode_type|
# +-------+------------+
# |      2|         Sea|
# |      3|        Land|
# |      9|Not reported|
# +-------+------------+

# %%
dim_mode.write.mode("overwrite").parquet('dim_mode')

# %% [markdown]
# #### 4.2 Data Quality Checks
# Explain the data quality checks you'll perform to ensure the pipeline ran as expected. These could include:
#  * Integrity constraints on the relational database (e.g., unique key, data type, etc.)
#  * Unit tests for the scripts to ensure they are doing the right thing
#  * Source/Count checks to ensure completeness
#
# Run Quality Checks

# %%
list_dir = ['dim_country', 'dim_demo', 'dim_port', 'dim_mode', 'dim_visa', 'immigration_fact']
for file_dir in list_dir:
    #if file_dir.is_dir():
    path = str(file_dir)
    df = spark.read.parquet(path)
    record_num = df.count()
    if record_num <= 0:
        raise ValueError("This table is empty!")
    else:
        print("Table - " + path.split('/')[-1] + f" - Records: {record_num}")
# Out:
# Table - dim_country - Records: 288
# Table - dim_demo - Records: 596
# Table - dim_port - Records: 22757
# Table - dim_mode - Records: 3
# Table - dim_visa - Records: 3
# Table - immigration_fact - Records: 3096313

# %%
list_dir = ['dim_country', 'dim_demo', 'dim_port', 'dim_mode', 'dim_visa', 'immigration_fact']

for file_dir in list_dir:
    path = str(file_dir)
    df = spark.read.parquet(path)
    unique = df.select(df.columns[0]).distinct().count()
    if df.count() > unique:
        raise ValueError(f"Table - {path} - Contains Duplicated Unique Key")
    else:
        print(f"Table - {path} - do not contains duplicated Unique Key")
# Out:
# Table - dim_country - do not contains duplicated Unique Key
# Table - dim_demo - do not contains duplicated Unique Key
# Table - dim_port - do not contains duplicated Unique Key
# Table - dim_mode - do not contains duplicated Unique Key
# Table - dim_visa - do not contains duplicated Unique Key
# Table - immigration_fact - do not contains duplicated Unique Key

# %% [markdown]
# #### 4.3 Data dictionary
# Provided on README.md file

# %% [markdown]
# #### Step 5: Complete Project Write Up
# 1. Clearly state the rationale for the choice of tools and technologies for the project.
# 2. Propose how often the data should be updated and why.
# 3. Write a description of how you would approach the problem differently under the following scenarios:
#  * The data was increased by 100x.
#  * The data populates a dashboard that must be updated on a daily basis by 7am every day.
#  * The database needed to be accessed by 100+ people.

# %% [markdown]
# #### 5.1
#
# The main purpose of this project is to process significant amount of immigration data provided aiming to construct an analytical environment optimized for Ad/Hoc queries.
#
# Therefore Apache Spark is one of the best tools to deal with data processing once it distributes the workload over different nodes.<br>
# The main ETL pipeline was constructed using Apache Spark through PySpark library which constructs analytical layer and enables data analysts to get insights of immigration in the U.S.

# %% [markdown]
# #### 5.2
#
# It depends on how frequently it will be analyzed (business rule). But the data can be updated daily once I94 data is partitioned by year and month.

# %% [markdown]
# #### 5.3
# - If the data was increased 100x it is advisable to increase the processing power using clusters with more nodes or cloud services e.g. AWS EMR which is a distributed data cluster for processing large amount of data.
# - Schedule the ETL pipeline to regulary update data. It could be done using Apache Airflow to orchestrate all the process, including data qality checks.
# - Data can be copied into Amazon Redshift, thus using RDS as the main analytical environment to store all the data and controll access thorugh IAM.
